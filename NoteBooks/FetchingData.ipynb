# %%
from google.colab import drive 
import os
import pandas as pd
import json
import requests

# %%
#loading data form drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/AIM_Task/dialect_dataset.csv"
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(path)
df.head()
# Out:
#                     id dialect
# 0  1175358310087892992      IQ
# 1  1175416117793349632      IQ
# 2  1175450108898565888      IQ
# 3  1175471073770573824      IQ
# 4  1175496913145217024      IQ

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458197 entries, 0 to 458196
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       458197 non-null  int64
#  1   dialect  458197 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 7.0+ MB

# %%
df['dialect'].value_counts()
# Out:
# EG    57636
# PL    43742
# KW    42109
# LY    36499
# QA    31069
# JO    27921
# LB    27617
# SA    26832
# AE    26296
# BH    26292
# OM    19116
# SY    16242
# DZ    16183
# IQ    15497
# SD    14434
# MA    11539
# YE     9927
# TN     9246
# Name: dialect, dtype: int64

# %%
#Converting Id columns to a list
ids = list(df['id'])
ids[:10]
# Out:
# [1175358310087892992,
#  1175416117793349632,
#  1175450108898565888,
#  1175471073770573824,
#  1175496913145217024,
#  1175668034146643968,
#  1175670153884983296,
#  1175671762580856832,
#  1175715664398561280,
#  1176019816072777728]

# %%
#Converting IDs from integer to string
str_ids = []
for i in ids:
    str_ids.append(str(i))

# %%
#Splitting IDs to chunks of size 1000
def split(lst, chunk_size):

  for i in range(0, len(lst), chunk_size):
    yield json.dumps(lst[i:i + chunk_size])

# %%
chunk_size = 1000

lst = list(split(str_ids, chunk_size))

# %%
lst[0]
# Out:
# '["1175358310087892992", "1175416117793349632", "1175450108898565888", "1175471073770573824", "1175496913145217024", "1175668034146643968", "1175670153884983296", "1175671762580856832", "1175715664398561280", "1176019816072777728", "1176068581487992832", "1176068868747538432", "1176198561941413888", "1176199622412427264", "1176460355939328000", "1176572872577474560", "1176608948671209472", "1176877065473274112", "1177172360455237632", "1177213425858109440", "1177527665886191616", "1177573850659414016", "1177621101331001088", "1177656196960047104", "1177694964026880000", "1178232178347524096", "1154854668780154880", "1154856299420692480", "1155420983433617408", "1155473383594831872", "1155559945942835200", "1155853950958100480", "1156082732197433088", "1156106460419563520", "1156107577312317440", "1156129807136149504", "1156133970536488960", "1157061856126754816", "1157235948192710912", "1157642091327119360", "1159153864890880000", "1159779766976860160", "1159848480623464448", "1159873484710916096", "1159888762450644992", "1159918464754225152", "1160071685950849024", "1160115076403257088", "1160197091718770688", "1160224130274406400", "1160289650126311424", "1160290300868382720", "1160298836314775552", "1160309756994752512", "1160421284737617920", "1160422458777907200", "1160482368353968128", "1160504147059326976", "1160853077014077440", "1160864334937042944", "1160954047769300992", "1161046172888444928", "1161257999111004160", "1161300388374634496", "1161300951640264704", "1161314878377906176", "1161318450620436480", "1161341660015538176", "1161400703866277888", "1161688000293720064", "1162052504378576896", "1162111319774040064", "1162111943500587008", "1162701800971165696", "1162708381767016448", "1164506262983315712", "1164566091076657152", "1164923540933611520", "1164931278069739520", "1165171702126514176", "1165966816776216576", "1166014307336957952", "1166268487536389888", "1166305797300772864", "1166652209838383104", "1166658909312094208", "1166956051356356608", "1167008948597264384", "1167018996350312448", "1167156077525393408", "1167472120630251520", "1167723349788618752", "1167727714780028928", "1168212960596176896", "1168482884820393984", "1168486929270300672", "1168582662715510784", "1168585361787895808", "1168585980309311488", "1168595763930324992", "1168860222670233600", "1172422887094902784", "1172589303245037568", "1173341162637336576", "1173490828225986560", "1173494697152667648", "1173624290660560896", "1173690889182556160", "1173697011843063808", "1173871533632184320", "1173888504352391168", "1174013183230730240", "1174014348173434880", "1174030763022532608", "1174607642406400000", "1174613453216108288", "1174615760318160896", "1174619626875080704", "1174666240394190848", "1174718790799638528", "1174726079770234880", "1174727377953468416", "1174948618324730112", "1174984039138119680", "1175014768337440768", "1175139635640623104", "1144322578753949568", "1144323820142104576", "1144330578965278848", "1144333996270206976", "1144503105209491584", "1144514563196489600", "1144559837541519360", "1144562648941518848", "1144563279282475008", "1144572613999628416", "1144573945376595968", "1144579175363350400", "1144583914419306368", "1144604204616552448", "1144637428361236352", "1144654908114837632", "1144907826906718208", "1144942972884140032", "1144951024245006336", "1144964913477165056", "1144980450563280768", "1144983073622241152", "1144983851502096384", "1144984436506841216", "1144990431920439168", "1145000424140935168", "1145008235000279040", "1145016641694158848", "1145065101969567616", "1145069624054206464", "1145070059859185664", "1145255876636401664", "1145256481475969024", "1145259836055203840", "1145371448422338560", "1145373318343798784", "1145376110382919552", "1145380698825658368", "1145422401808883584", "1145444736653770752", "1145445873184313216", "1145446249384095616", "1145621047368138752", "1145752685339193216", "1145984262778343424", "1146114092396163200", "1146115624244056064", "114611641921978777 ...

# %%
#Make request to get Json data
json_lst = []
for i in range(len(lst)):
    response = requests.post('https://recruitment.aimtechnologies.co/ai-tasks',  data=lst[i])
    json_lst.append(response.json())

# %%
#Mapping Json data to Dictionary
finalMap = {}
for d in json_lst:
    finalMap.update(d)

# %%
len(finalMap)
# Out:
# 458197

# %%
type(finalMap)
# Out:
# dict

# %%
#Saving tweets to csv file
text_df = pd.DataFrame(finalMap.items(), columns=['id', 'text'])

# %%
text_df.head()
# Out:
#                     id                                               text
# 0  1175358310087892992   @Nw8ieJUwaCAAreT لكن بالنهاية .. ينتفض .. يغير .
# 1  1175416117793349632  @7zNqXP0yrODdRjK يعني هذا محسوب على البشر .. ح...
# 2  1175450108898565888                    @KanaanRema مبين من كلامه خليجي
# 3  1175471073770573824         @HAIDER76128900 يسلملي مرورك وروحك الحلوه💐
# 4  1175496913145217024                 @hmo2406 وين هل الغيبه  اخ محمد 🌸🌺

# %%
text_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458197 entries, 0 to 458196
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      458197 non-null  object
#  1   text    458197 non-null  object
# dtypes: object(2)
# memory usage: 7.0+ MB

# %%
text_df.to_csv('/content/drive/MyDrive/AIM_Task/requested_data.csv', index=False)

# %%
t = pd.read_csv('/content/drive/MyDrive/AIM_Task/requested_data.csv', lineterminator='\n')

# %%
t.head()
# Out:
#                     id                                               text
# 0  1175358310087892992   @Nw8ieJUwaCAAreT لكن بالنهاية .. ينتفض .. يغير .
# 1  1175416117793349632  @7zNqXP0yrODdRjK يعني هذا محسوب على البشر .. ح...
# 2  1175450108898565888                    @KanaanRema مبين من كلامه خليجي
# 3  1175471073770573824         @HAIDER76128900 يسلملي مرورك وروحك الحلوه💐
# 4  1175496913145217024                 @hmo2406 وين هل الغيبه  اخ محمد 🌸🌺
